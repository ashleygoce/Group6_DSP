# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = np.linspace(-10,10,21)

def  step (N):
    return np.where(N>=0,1,0)

plt.stem(N, step(N))

plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
N = np.linspace(-2*np.pi, 2*np.pi, 100)

plt.figure(figsize=(10,4))
plt.title('Amplitude Shift')
plt.plot(N,np.sin(N), label=r'$\sin \theta$')
plt.plot(N,np,sin(N), label=r'$2\sin \theta$')

plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 plt.title('Amplitude Shift')
#       5 plt.plot(N,np.sin(N), label=r'$\sin \theta$')
# ----> 6 plt.plot(N,np,sin(N), label=r'$2\sin \theta$')
#       8 plt.legend()
#       9 plt.grid()
#
# NameError: name 'sin' is not defined

# %%
plt.figure(figsize=(10,4))
plt.title('Frequency Shift')
plt.plot(N,np.sin(N),label=r'$\sin\theta$')
plt.plot(N, np.sin(2*N),label=r'$\sin 2\theta$')

plt.legend()
plt.grid()
plt.show()
